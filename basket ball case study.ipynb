# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
# Total features are 17, out of which 1 is float type and remaining are integer.
# No null values are present in tha dataset

# %%
df.shape
# Out:
# (30, 17)

# %%
df.describe().T
# Out:
#      count         mean         std      min        25%       50%      75%  \
# W     30.0    80.966667   10.453455    63.00    74.0000    81.000    87.75
# R     30.0   688.233333   58.761754   573.00   651.2500   689.000   718.25
# AB    30.0  5516.266667   70.467372  5385.00  5464.0000  5510.000  5570.00
# H     30.0  1403.533333   57.140923  1324.00  1363.0000  1382.500  1451.50
# 2B    30.0   274.733333   18.095405   236.00   262.2500   275.500   288.75
# 3B    30.0    31.300000   10.452355    13.00    23.0000    31.000    39.00
# HR    30.0   163.633333   31.823309   100.00   140.2500   158.500   177.00
# BB    30.0   469.100000   57.053725   375.00   428.2500   473.000   501.25
# SO    30.0  1248.200000  103.759470   973.00  1157.5000  1261.500  1311.50
# SB    30.0    83.500000   22.815225    44.00    69.0000    83.500    96.50
# RA    30.0   688.233333   72.108005   525.00   636.2500   695.500   732.50
# ...

# %%
df.W.unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %%
#Analyse Target variable first
sns.distplot(df.W)
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %% [markdown]
# observation - it seems like a normal distribution

# %%
sns.histplot(df.W, bins=40)
# Out:
# <AxesSubplot:xlabel='W', ylabel='Count'>

# %%
for i in df.columns:
    sns.distplot(df[i])
    plt.show()

# %%
# R  -  is right skewed data and 2 peaks
# AB  - kind of normal distribution
# H - Bipolar distributed data
#2B  -left skewed data
#3B  -normal distribution
# HR - skewness on both side
#BB  -skewness on both side
# SO  - skewed data on both sides
#SB- right side skewed
#RA - skewed data
# ER  - skewed data
# ERA - Skewed on both side
# CG - not normal distributed data
#SHO= not normal distributed
#SV - right skewed
#E Bipolar data

# %% [markdown]
# checking null  values

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
sns.heatmap(df.isna())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# observation - no null values present

# %% [markdown]
# # correlation

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
#reframing
df=df[['R','AB','H','2B','3B','HR','BB','SO','SB','RA','ER','ERA','CG','SHO','SV','E','W']]

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True,linecolor='Blue',linewidth=.35)
# Out:
# <AxesSubplot:>

# %%
#R, HR, 2B , BB , SHO,SV are higly correlated with target variable
#AB, H, 3B, SO,SB, CG, E are low correlated with target variable
#RA, ER, ERA share negative correlation with target variable

# %%
#bivariate analysis

# %%
df.columns
# Out:
# Index(['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER', 'ERA',
#        'CG', 'SHO', 'SV', 'E', 'W'],
#       dtype='object')

# %%
sns.scatterplot('R','W',data=df)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %%
#positive correlation

# %%
sns.scatterplot('AB','W',data=df)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='W'>

# %%
#not normal distribution

# %%
sns.scatterplot('H','W',data=df)
# Out:
# <AxesSubplot:xlabel='H', ylabel='W'>

# %%
#scattered data

# %%
sns.scatterplot('2B','W',data=df)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='W'>

# %%
#positive correlation

# %%
df.columns
# Out:
# Index(['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER', 'ERA',
#        'CG', 'SHO', 'SV', 'E', 'W'],
#       dtype='object')

# %%
sns.scatterplot('3B','W',data=df)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='W'>

# %%
#WIDE SPREAD OF DATA.

# %%
sns.scatterplot('HR','W',data=df)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='W'>

# %%
#POSITIVE COORRELATION

# %%
sns.scatterplot('BB','W',data=df)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='W'>

# %%
#POSITIVE CORRELATION

# %%
sns.scatterplot('SHO','W',data=df)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='W'>

# %%
#LOW CORRELATION

# %%
df.columns
# Out:
# Index(['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER', 'ERA',
#        'CG', 'SHO', 'SV', 'E', 'W'],
#       dtype='object')

# %%
sns.scatterplot('SB','W',data=df)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='W'>

# %%
#LOW CORRELATION

# %%
sns.scatterplot('RA','W',data=df)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='W'>

# %%
#HIGHLY NEGATIVE

# %%
sns.scatterplot('ER','W',data=df)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='W'>

# %%
#NEGATIVE CORRELATION

# %%
sns.scatterplot('ERA','W',data=df)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='W'>

# %%
#HIGHLY NEGATIVE CORRELATION

# %%
sns.scatterplot('CG','W',data=df)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='W'>

# %%
#LOW CORRELTION

# %%
sns.scatterplot('SV','W',data=df)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='W'>

# %%
#POSITIVE CORRELATION

# %%
sns.scatterplot('E','W',data=df)
# Out:
# <AxesSubplot:xlabel='E', ylabel='W'>

# %%
#LOW CORRELATION

# %%
#some features are negativelu correlated and some data is spreaded annd some have positive correlation

# %%
df
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5   891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# ...

# %%
sns.scatterplot('R','W',hue='AB',data=df)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %%
sns.scatterplot('H','W',hue='2B',data=df)
# Out:
# <AxesSubplot:xlabel='H', ylabel='W'>

# %%
sns.scatterplot('3B','W',hue='HR',data=df)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='W'>

# %%
sns.scatterplot('BB','W',hue='SO',data=df)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='W'>

# %%
sns.scatterplot('SB','W',hue='RA',data=df)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='W'>

# %%
#unique values

# %%
for i in df.columns:
    df[i].nunique()
    print("unique features",i,'=',df[i].nunique())
# Out:
# unique features R = 28
# unique features AB = 29
# unique features H = 29
# unique features 2B = 22
# unique features 3B = 23
# unique features HR = 27
# unique features BB = 29
# unique features SO = 29
# unique features SB = 27
# unique features RA = 30
# unique features ER = 30
# unique features ERA = 30
# unique features CG = 9
# unique features SHO = 12
# unique features SV = 20
# unique features E = 21
# unique features W = 24

# %%
sns.scatterplot('R','W',hue='CG',data=df)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %%
sns.scatterplot('CG','W',hue='ERA',data=df)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='W'>

# %%
sns.scatterplot('ER','ERA',hue='RA',data=df)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='ERA'>

# %%
#REMOVAL OF MUULTICOLINEARITY

# %%
m =  df.drop('W',axis=1)
m.head()
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  SV  \
# 0  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8  56
# 1  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12  45
# 2  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10  38
# 3  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9  37
# 4  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12  35
#
#      E
# 0   88
# 1   86
# 2   79
# 3  101
# 4   86

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaling = sc.fit_transform(m)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
VIF= pd.DataFrame()
VIF['features']=m.columns

# %%
VIF['vif']=[variance_inflation_factor(scaling,i) for i in range(len(m.columns))]

# %%
VIF
# Out:
#    features          vif
# 0         R    11.522370
# 1        AB    13.311532
# 2         H    10.070668
# 3        2B     4.019297
# 4        3B     3.294146
# 5        HR    10.079902
# 6        BB     3.806098
# 7        SO     2.652401
# 8        SB     2.102684
# 9        RA   191.839155
# 10       ER  1680.387145
# 11      ERA  1222.722240
# 12       CG     3.059904
# 13      SHO     3.654331
# 14       SV     5.798850
# 15        E     2.186219

# %%
#drooping columns with HIGH VIF

# %%
m = df.drop(['W','ER','ERA'],axis=1)

# %%
m
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA  CG  SHO  SV    E
# 0   724  5575  1497  300  42  139  383   973  104  641   2    8  56   88
# 1   696  5467  1349  277  44  156  439  1264   70  700   2   12  45   86
# 2   669  5439  1395  303  29  141  533  1157   86  640  11   10  38   79
# 3   622  5533  1381  260  27  136  404  1231   68  701   7    9  37  101
# 4   689  5605  1515  289  49  151  455  1259   83  803   7   12  35   86
# 5   891  5509  1480  308  17  232  570  1151   88  670   7   10  34   88
# 6   764  5567  1397  272  19  212  554  1227   63  698   3    4  48   93
# 7   713  5485  1370  246  20  217  418  1331   44  693   0   10  43   77
# 8   644  5485  1383  278  32  167  436  1310   87  642   1   12  60   95
# 9   748  5640  1495  294  33  161  478  1148   71  753   3   10  40   97
# 10  751  5511  1419  279  32  172  503  1233  101  733   5    9  45  119
# 11  729  5459  1363  278  26  230  486  1392  121  618   5   13  39   85
# ...

# %%
scaling=sc.fit_transform(m)

# %%
VIF2=pd.DataFrame()
VIF2['features']=m.columns
VIF2['vif']=[variance_inflation_factor(scaling,i) for i in range(len(m.columns))]

# %%
VIF2
# Out:
#    features        vif
# 0         R  10.791320
# 1        AB   4.369242
# 2         H   8.568511
# 3        2B   3.667399
# 4        3B   2.998994
# 5        HR   7.586684
# 6        BB   3.541589
# 7        SO   2.181428
# 8        SB   1.844092
# 9        RA   5.068366
# 10       CG   2.723889
# 11      SHO   3.383050
# 12       SV   3.110481
# 13        E   2.072298

# %%
m = df.drop(['W','ER','ERA','RA'],axis=1)

# %%
scaling=sc.fit_transform(m)

# %%
vif=pd.DataFrame()
vif['features']=m.columns
vif['vif']=[variance_inflation_factor(scaling,i) for i in range(len(m.columns))]

# %%
vif
# Out:
#    features        vif
# 0         R  10.009588
# 1        AB   4.365164
# 2         H   7.793753
# 3        2B   3.431311
# 4        3B   2.505213
# 5        HR   7.328372
# 6        BB   3.390692
# 7        SO   2.154773
# 8        SB   1.597740
# 9        CG   2.723353
# 10      SHO   1.688683
# 11       SV   2.082425
# 12        E   1.937035

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True,linecolor='white',linewidth=.35)
# Out:
# <AxesSubplot:>

# %%
#skewness

# %%
m.skew()
# Out:
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
#outliers

# %%
for i in m.columns:
    sns.boxplot(m[i])
    plt.show()

# %%
IQR=df['R'].quantile(.75)-df['R'].quantile(.25)
IQR
uppeer= df['R'].quantile(.75)+(1.5*IQR)
uppeer
# Out:
# 818.75

# %%
m['R']=np.where(m['R']>uppeer,uppeer,m['R'])

# %%
IQR=df['SV'].quantile(.75)-df['SV'].quantile(.25)
IQR
uppeer= df['SV'].quantile(.75)+(1.5*IQR)
uppeer
# Out:
# 61.0

# %%
m['SV']=np.where(m['SV']>uppeer,uppeer,m['SV'])

# %%
IQR=df['SHO'].quantile(.75)-df['SHO'].quantile(.25)
IQR
uppeer= df['SHO'].quantile(.75)+(1.5*IQR)
uppeer
# Out:
# 19.0

# %%
m['SHO']=np.where(m['SHO']>uppeer,uppeer,m['SHO'])

# %%
IQR=df['E'].quantile(.75)-df['E'].quantile(.25)
IQR
uppeer= df['E'].quantile(.75)+(1.5*IQR)
uppeer
# Out:
# 112.875

# %%
m['E']=np.where(m['E']>uppeer,uppeer,m['E'])

# %%
for i in m.columns:
    sns.boxplot(m[i])
    plt.show()

# %%
m.columns
# Out:
# Index(['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'CG', 'SHO', 'SV',
#        'E'],
#       dtype='object')

# %%
#skewness handling

# %%
from sklearn.preprocessing import power_transform
transform=power_transform(m)

# %%
transform =pd.DataFrame(transform)
transform.columns=m.columns

# %%
transform.skew()
# Out:
# R      0.000000
# AB     0.000000
# H      0.000000
# 2B    -0.035315
# 3B    -0.072933
# HR    -0.000065
# BB    -0.007760
# SO     0.041170
# SB    -0.010455
# CG    -0.059785
# SHO   -0.017889
# SV     0.001270
# E      0.032939
# dtype: float64

# %%
#scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scale= sc.fit_transform(transform)

# %%
x=scale

# %%
y=df['W']

# %%
x.shape
# Out:
# (30, 13)

# %%
y.shape
# Out:
# (30,)

# %% [markdown]
# # MACHINE LEARNING

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
lr=LinearRegression()

# %%
for i in range(1,500):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.2)
    lr.fit(x_train,y_train)
    trainpred=lr.predict(x_train)
    testpred=lr.predict(x_test)
    if round(r2_score(y_test,testpred),2)==round(r2_score(y_train,trainpred),2):
        print("at random state",i,'model performs very well')
        print("test r2 score ", round(r2_score(y_test,testpred),2))
        print("train r2 score ", round(r2_score(y_train,trainpred),2))
# Out:
# at random state 14 model performs very well
# test r2 score  0.76
# train r2 score  0.76
# at random state 225 model performs very well
# test r2 score  0.73
# train r2 score  0.73

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=14,test_size=.2)
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#approaching more regressors

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

from sklearn.linear_model import Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
lr=LinearRegression()
rd = Ridge()
ls = Lasso()
dtr= DecisionTreeRegressor()
svr= SVR()
knr = KNeighborsRegressor()
elastic = ElasticNet()
bg= BaggingRegressor()
ada= AdaBoostRegressor()
Gb= GradientBoostingRegressor()

# %%
k = [lr,rd,dtr,svr,knr,elastic,bg,ada,Gb]

# %%
for m in model:
    m.fit(x_train,y_train)
    print('mean_absolute_error of ',m ,'model', mean_absolute_error(y_test,m.predict(x_test)))
    print('mean_square_error of',m,'model' , mean_squared_error(y_test,m.predict(x_test)))
    print('R2 Score of',m,'model', r2_score(y_test,m.predict(x_test) )*100)
    print('X' * 50, '\n\n')

# %%
for i in k:
    i.fit(x_train,y_train)
    print("Mean absolute error",i,'k',mean_absolute_error(y_test,i.predict(x_test)))
    print('mean_square_error',i,'k',mean_squared_error(y_test,i.predict(x_test)))
    print('r2_score',i,'k',r2_score(y_test,i.predict(x_test))*100)
    print('x'*50,'\n\n')
# Out:
# Mean absolute error LinearRegression() k 4.307777131067513
# mean_square_error LinearRegression() k 25.60017037428538
# r2_score LinearRegression() k 76.27172673856144
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# Mean absolute error Ridge() k 4.247022451075725
# mean_square_error Ridge() k 24.196753636132254
# r2_score Ridge() k 77.57252495106177
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# Mean absolute error DecisionTreeRegressor() k 11.5
# mean_square_error DecisionTreeRegressor() k 160.5
# r2_score DecisionTreeRegressor() k -48.76416065911431
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# Mean absolute error SVR() k 8.018657925464234
# mean_square_error SVR() k 104.61445580277717
# r2_score SVR() k 3.0350049201859464
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# Mean absolute error KNeighborsRegressor() k 6.466666666666669
# mean_square_error KNeighborsRegressor() k 62.733333333333356
# ...

# %%
#cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in k:
    print("mean_square of",i,'k',mean_squared_error(y_test,i.predict(x_test)))
    print("corr validation score of",i,"is",cross_val_score(i,x,y,cv=10,scoring='neg_mean_squared_error').mean())
    print('*'*50)
# Out:
# mean_square of LinearRegression() k 25.60017037428538
# corr validation score of LinearRegression() is -76.0774092024006
# **************************************************
# mean_square of Ridge() k 24.196753636132254
# corr validation score of Ridge() is -73.05216408214886
# **************************************************
# mean_square of DecisionTreeRegressor() k 160.5
# corr validation score of DecisionTreeRegressor() is -143.16666666666669
# **************************************************
# mean_square of SVR() k 104.61445580277717
# corr validation score of SVR() is -105.29837814291042
# **************************************************
# mean_square of KNeighborsRegressor() k 62.733333333333356
# corr validation score of KNeighborsRegressor() is -79.33866666666668
# **************************************************
# mean_square of ElasticNet() k 35.1964250196166
# corr validation score of ElasticNet() is -68.71400275049123
# ...

# %%
for i in k:
    print('root mean square of',i,'k',np.sqrt(mean_squared_error(y_test,i.predict(x_test))))
    score=cross_val_score(i,x,y,cv=10,scoring='neg_mean_squared_error').mean()
    print("cross validation score of root mean square",i,"=",np.sqrt(-score))
    print('*'*50)
# Out:
# root mean square of LinearRegression() k 5.059661092828786
# cross validation score of root mean square LinearRegression() = 8.72223647938994
# **************************************************
# root mean square of Ridge() k 4.919019580783579
# cross validation score of root mean square Ridge() = 8.54705587217896
# **************************************************
# root mean square of DecisionTreeRegressor() k 12.668859459319927
# cross validation score of root mean square DecisionTreeRegressor() = 12.545915670049755
# **************************************************
# root mean square of SVR() k 10.228120834384837
# cross validation score of root mean square SVR() = 10.261499799878692
# **************************************************
# root mean square of KNeighborsRegressor() k 7.920437698343025
# cross validation score of root mean square KNeighborsRegressor() = 8.907225531368715
# **************************************************
# ...

# %%
#hyper tuning of svr

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {'kernel' : ['poly','linear','rbf'],
         'gamma': ['scale','auto']}

# %%
GCV= GridSearchCV(svr,params,cv=5,scoring='neg_mean_squared_error',n_jobs=-1)
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVR(), n_jobs=-1,
#              param_grid={'gamma': ['scale', 'auto'],
#                          'kernel': ['poly', 'linear', 'rbf']},
#              scoring='neg_mean_squared_error')

# %%
GCV.best_params_
# Out:
# {'gamma': 'scale', 'kernel': 'linear'}

# %%
GCV_pred=GCV.best_estimator_.predict(x_test)
mean_squared_error(y_test,GCV_pred)
# Out:
# 31.873389705861694

# %%
import joblib

# %%
joblib.dump(GCV.best_estimator_,"Basketball.pkl")
# Out:
# ['Basketball.pkl']
